# %% [markdown]
# Chapter 2: Python Infrastructure

# %%
import numpy as np

# %%
a = np.random.standard_normal((5,3))

# %%
import pandas as pd

# %%
df = pd.DataFrame(a, columns=['a','b','c'])

# %%
df
# Out:
#           a         b         c
# 0 -0.931365  1.460753 -0.398832
# 1  0.100739 -1.019257  0.923144
# 2  0.639953  1.037418 -0.135054
# 3  0.626473 -0.610370 -0.121451
# 4 -1.102402 -1.667621 -0.705109

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       5 non-null      float64
#  1   b       5 non-null      float64
#  2   c       5 non-null      float64
# dtypes: float64(3)
# memory usage: 252.0 bytes
