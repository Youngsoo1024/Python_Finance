# %% [markdown]
# ## Chapter 5. Data Analysis with pandas

# %%
import pandas as pd

# %%
df= pd.DataFrame([10, 20, 30, 40], columns=['numbers'], index=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['numbers'], dtype='object')

# %%
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.loc[['a', 'd']]
# Out:
#    numbers
# a       10
# d       40

# %%
df.iloc[1:3]
# Out:
#    numbers
# b       20
# c       30

# %%
df.sum()
# Out:
# numbers    100
# dtype: int64

# %%
df.apply(lambda x:x**2)
# uses the apply() method to calculate squares in vertorized fashion
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df**2
# Applies vectorization directly as with adarray objects
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df['floats'] = (1.5, 2.5, 3.5, 4.5)

# %%
df
# Out:
#    numbers  floats
# a       10     1.5
# b       20     2.5
# c       30     3.5
# d       40     4.5

# %%
df['floats']
# Select this column and shows its data and index labels
# Out:
# a    1.5
# b    2.5
# c    3.5
# d    4.5
# Name: floats, dtype: float64

# %%
df['names'] = pd.DataFrame(['Yves', 'Sandra', 'Lilli', 'Henry'], index =['d', 'a', 'b', 'c'])

# %%
df
# Out:
#    numbers  floats   names
# a       10     1.5  Sandra
# b       20     2.5   Lilli
# c       30     3.5   Henry
# d       40     4.5    Yves

# %%
df = pd.concat([df, pd.DataFrame([{'numbers': 100, 'floats': 5.75,
'names': 'Jil'}], index=['y',])])

# %%
df
# Out:
#    numbers  floats   names
# a       10    1.50  Sandra
# b       20    2.50   Lilli
# c       30    3.50   Henry
# d       40    4.50    Yves
# y      100    5.75     Jil

# %%
df = pd.concat([df, pd.DataFrame([{'names' :'Liz'}], index=['z',])])

# %%
df
# Out:
#    numbers  floats   names
# a     10.0    1.50  Sandra
# b     20.0    2.50   Lilli
# c     30.0    3.50   Henry
# d     40.0    4.50    Yves
# y    100.0    5.75     Jil
# z      NaN     NaN     Liz

# %%
df.dtypes
# Out:
# numbers    float64
# floats     float64
# names       object
# dtype: object

# %%
df[['numbers','floats']].mean()
# Out:
# numbers    40.00
# floats      3.55
# dtype: float64

# %%
df[['numbers','floats']].std()
# Out:
# numbers    35.355339
# floats      1.662077
# dtype: float64

# %%
import numpy as np

# %%
np.random.seed(100)

# %%
a = np.random.standard_normal((9,4))

# %%
a
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#           0         1         2         3
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df.columns = ['No1', 'No2', 'No3', 'No4']

# %%
df
# Out:
#         No1       No2       No3       No4
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df['No2'].mean()
# Out:
# np.float64(0.7010330941456459)

# %%
dates = pd.date_range('2019-1-1', periods = 9, freq = 'ME')

# %%
dates
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30'],
#               dtype='datetime64[ns]', freq='ME')

# %%
df.index = dates

# %%
df
# Out:
#                  No1       No2       No3       No4
# 2019-01-31 -1.749765  0.342680  1.153036 -0.252436
# 2019-02-28  0.981321  0.514219  0.221180 -1.070043
# 2019-03-31 -0.189496  0.255001 -0.458027  0.435163
# 2019-04-30 -0.583595  0.816847  0.672721 -0.104411
# 2019-05-31 -0.531280  1.029733 -0.438136 -1.118318
# 2019-06-30  1.618982  1.541605 -0.251879 -0.842436
# 2019-07-31  0.184519  0.937082  0.731000  1.361556
# 2019-08-31 -0.326238  0.055676  0.222400 -1.443217
# 2019-09-30 -0.756352  0.816454  0.750445 -0.455947

# %%
df.values
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
np.array(df)
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9 entries, 2019-01-31 to 2019-09-30
# Freq: ME
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No1     9 non-null      float64
#  1   No2     9 non-null      float64
#  2   No3     9 non-null      float64
#  3   No4     9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0 bytes

# %%
df.describe()
# Out:
#             No1       No2       No3       No4
# count  9.000000  9.000000  9.000000  9.000000
# mean  -0.150212  0.701033  0.289193 -0.387788
# std    0.988306  0.457685  0.579920  0.877532
# min   -1.749765  0.055676 -0.458027 -1.443217
# 25%   -0.583595  0.342680 -0.251879 -1.070043
# 50%   -0.326238  0.816454  0.222400 -0.455947
# 75%    0.184519  0.937082  0.731000 -0.104411
# max    1.618982  1.541605  1.153036  1.361556

# %%
df.sum()
# Out:
# No1   -1.351906
# No2    6.309298
# No3    2.602739
# No4   -3.490089
# dtype: float64

# %%
df.mean()
# Out:
# No1   -0.150212
# No2    0.701033
# No3    0.289193
# No4   -0.387788
# dtype: float64

# %%
df.mean(axis=0)
#column wise mena value
# Out:
# No1   -0.150212
# No2    0.701033
# No3    0.289193
# No4   -0.387788
# dtype: float64

# %%
df.mean(axis=1)
#row wise mean value
# Out:
# 2019-01-31   -0.126621
# 2019-02-28    0.161669
# 2019-03-31    0.010661
# 2019-04-30    0.200390
# 2019-05-31   -0.264500
# 2019-06-30    0.516568
# 2019-07-31    0.803539
# 2019-08-31   -0.372845
# 2019-09-30    0.088650
# Freq: ME, dtype: float64

# %%
df.cumsum()
#column wise cumulative sum (starting at first index postion)
# Out:
#                  No1       No2       No3       No4
# 2019-01-31 -1.749765  0.342680  1.153036 -0.252436
# 2019-02-28 -0.768445  0.856899  1.374215 -1.322479
# 2019-03-31 -0.957941  1.111901  0.916188 -0.887316
# 2019-04-30 -1.541536  1.928748  1.588909 -0.991727
# 2019-05-31 -2.072816  2.958480  1.150774 -2.110045
# 2019-06-30 -0.453834  4.500086  0.898895 -2.952481
# 2019-07-31 -0.269316  5.437168  1.629895 -1.590925
# 2019-08-31 -0.595554  5.492844  1.852294 -3.034142
# 2019-09-30 -1.351906  6.309298  2.602739 -3.490089

# %%
np.mean(df, axis=0)
# Out:
# No1   -0.150212
# No2    0.701033
# No3    0.289193
# No4   -0.387788
# dtype: float64

# %%
np.log(df)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#                  No1       No2       No3       No4
# 2019-01-31       NaN -1.070957  0.142398       NaN
# 2019-02-28 -0.018856 -0.665106 -1.508780       NaN
# 2019-03-31       NaN -1.366486       NaN -0.832033
# 2019-04-30       NaN -0.202303 -0.396425       NaN
# 2019-05-31       NaN  0.029299       NaN       NaN
# 2019-06-30  0.481797  0.432824       NaN       NaN
# 2019-07-31 -1.690005 -0.064984 -0.313341  0.308628
# 2019-08-31       NaN -2.888206 -1.503279       NaN
# 2019-09-30       NaN -0.202785 -0.287089       NaN

# %%
np.sqrt(abs(df))
# Out:
#                  No1       No2       No3       No4
# 2019-01-31  1.322787  0.585389  1.073795  0.502430
# 2019-02-28  0.990616  0.717091  0.470297  1.034429
# 2019-03-31  0.435311  0.504977  0.676777  0.659669
# 2019-04-30  0.763934  0.903796  0.820196  0.323127
# 2019-05-31  0.728890  1.014757  0.661918  1.057506
# 2019-06-30  1.272392  1.241614  0.501876  0.917843
# 2019-07-31  0.429556  0.968030  0.854986  1.166857
# 2019-08-31  0.571173  0.235958  0.471593  1.201340
# 2019-09-30  0.869685  0.903578  0.866282  0.675238

# %%
np.sqrt(abs(df)).sum()
# Out:
# No1    7.384345
# No2    7.075190
# No3    6.397719
# No4    7.538440
# dtype: float64

# %%
100*df+100
# Out:
#                    No1         No2         No3         No4
# 2019-01-31  -74.976547  134.268040  215.303580   74.756396
# 2019-02-28  198.132079  151.421884  122.117967   -7.004333
# 2019-03-31   81.050417  125.500144   54.197301  143.516349
# 2019-04-30   41.640495  181.684707  167.272081   89.558886
# 2019-05-31   46.871962  202.973269   56.186438  -11.831825
# 2019-06-30  261.898166  254.160517   74.812086   15.756426
# 2019-07-31  118.451869  193.708220  173.100034  236.155613
# 2019-08-31   67.376194  105.567601  122.239961  -44.321700
# 2019-09-30   24.364769  181.645401  175.044476   54.405307

# %%
from pylab import plt, mpl
plt.style.use('seaborn-v0_8')
mpl.rcParams['font.family'] ='serif'
# %matplotlib inline

# %%
df.cumsum().plot(lw=2.0, figsize=(10,6))
# Out:
# <Axes: >

# %%
df.plot.bar(figsize=(10,6), rot=15)
#df.plot(kind='bar), figsize=(10,6))
# Out:
# <Axes: >

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
S = pd.Series(np.linspace(0,15,7), name='series')

# %%
S
# Out:
# 0     0.0
# 1     2.5
# 2     5.0
# 3     7.5
# 4    10.0
# 5    12.5
# 6    15.0
# Name: series, dtype: float64

# %%
type(S)
# Out:
# pandas.core.series.Series

# %%
s=df['No1']

# %%
s
# Out:
# 2019-01-31   -1.749765
# 2019-02-28    0.981321
# 2019-03-31   -0.189496
# 2019-04-30   -0.583595
# 2019-05-31   -0.531280
# 2019-06-30    1.618982
# 2019-07-31    0.184519
# 2019-08-31   -0.326238
# 2019-09-30   -0.756352
# Freq: ME, Name: No1, dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.mean()
# Out:
# np.float64(-0.15021177307319458)

# %%
s.plot(lw=2.0, figsize=(10,6))
# Out:
# <Axes: >

# %%
df['Quarter'] = ['Q1', 'Q1', 'Q1', 'Q2', 'Q2', 'Q2', 'Q3','Q3','Q3']

# %%
df
# Out:
#                  No1       No2       No3       No4 Quarter
# 2019-01-31 -1.749765  0.342680  1.153036 -0.252436      Q1
# 2019-02-28  0.981321  0.514219  0.221180 -1.070043      Q1
# 2019-03-31 -0.189496  0.255001 -0.458027  0.435163      Q1
# 2019-04-30 -0.583595  0.816847  0.672721 -0.104411      Q2
# 2019-05-31 -0.531280  1.029733 -0.438136 -1.118318      Q2
# 2019-06-30  1.618982  1.541605 -0.251879 -0.842436      Q2
# 2019-07-31  0.184519  0.937082  0.731000  1.361556      Q3
# 2019-08-31 -0.326238  0.055676  0.222400 -1.443217      Q3
# 2019-09-30 -0.756352  0.816454  0.750445 -0.455947      Q3

# %%
groups = df.groupby('Quarter')

# %%
groups.size()
# Out:
# Quarter
# Q1    3
# Q2    3
# Q3    3
# dtype: int64

# %%
groups.mean()
# Out:
#               No1       No2       No3       No4
# Quarter
# Q1      -0.319314  0.370634  0.305396 -0.295772
# Q2       0.168035  1.129395 -0.005765 -0.688388
# Q3      -0.299357  0.603071  0.567948 -0.179203

# %%
groups.max()
# Out:
#               No1       No2       No3       No4
# Quarter
# Q1       0.981321  0.514219  1.153036  0.435163
# Q2       1.618982  1.541605  0.672721 -0.104411
# Q3       0.184519  0.937082  0.750445  1.361556

# %%
groups.aggregate([min, max]).round(2)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5940\2168091236.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   groups.aggregate([min, max]).round(2)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5940\2168091236.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   groups.aggregate([min, max]).round(2)
#           No1         No2         No3         No4
#           min   max   min   max   min   max   min   max
# Quarter
# Q1      -1.75  0.98  0.26  0.51 -0.46  1.15 -1.07  0.44
# Q2      -0.58  1.62  0.82  1.54 -0.44  0.67 -1.12 -0.10
# Q3      -0.76  0.18  0.06  0.94  0.22  0.75 -1.44  1.36

# %%
df['Odd_Even'] = ['Odd', 'Even','Odd', 'Even','Odd', 'Even','Odd', 'Even','Odd']

# %%
groups = df.groupby(['Quarter', 'Odd_Even'])

# %%
groups.size()
# Out:
# Quarter  Odd_Even
# Q1       Even        1
#          Odd         2
# Q2       Even        2
#          Odd         1
# Q3       Even        1
#          Odd         2
# dtype: int64

# %%
groups[['No1','No4']].aggregate([sum, np.mean])
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5940\4184550461.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   groups[['No1','No4']].aggregate([sum, np.mean])
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5940\4184550461.py:1: FutureWarning: The provided callable <function mean at 0x000001E8C0940680> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   groups[['No1','No4']].aggregate([sum, np.mean])
#                        No1                 No4
#                        sum      mean       sum      mean
# Quarter Odd_Even
# Q1      Even      0.981321  0.981321 -1.070043 -1.070043
#         Odd      -1.939261 -0.969631  0.182727  0.091364
# Q2      Even      1.035387  0.517693 -0.946847 -0.473423
#         Odd      -0.531280 -0.531280 -1.118318 -1.118318
# Q3      Even     -0.326238 -0.326238 -1.443217 -1.443217
#         Odd      -0.571834 -0.285917  0.905609  0.452805

# %%
df
# Out:
#                  No1       No2       No3       No4 Quarter Odd_Even
# 2019-01-31 -1.749765  0.342680  1.153036 -0.252436      Q1      Odd
# 2019-02-28  0.981321  0.514219  0.221180 -1.070043      Q1     Even
# 2019-03-31 -0.189496  0.255001 -0.458027  0.435163      Q1      Odd
# 2019-04-30 -0.583595  0.816847  0.672721 -0.104411      Q2     Even
# 2019-05-31 -0.531280  1.029733 -0.438136 -1.118318      Q2      Odd
# 2019-06-30  1.618982  1.541605 -0.251879 -0.842436      Q2     Even
# 2019-07-31  0.184519  0.937082  0.731000  1.361556      Q3      Odd
# 2019-08-31 -0.326238  0.055676  0.222400 -1.443217      Q3     Even
# 2019-09-30 -0.756352  0.816454  0.750445 -0.455947      Q3      Odd

# %%
data = np.random.standard_normal((10,2))

# %%
df = pd.DataFrame(data, columns = ['x', 'y'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       10 non-null     float64
#  1   y       10 non-null     float64
# dtypes: float64(2)
# memory usage: 292.0 bytes

# %%
df.head()
# Out:
#           x         y
# 0  1.189622 -1.690617
# 1 -1.356399 -1.232435
# 2 -0.544439 -0.668172
# 3  0.007315 -0.612939
# 4  1.299748 -1.733096

# %%
df.tail()
# Out:
#           x         y
# 5 -0.983310  0.357508
# 6 -1.613579  1.470714
# 7 -1.188018 -0.549746
# 8 -0.940046 -0.827932
# 9  0.108863  0.507810

# %%
df['x']>0.5
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: x, dtype: bool

# %%
(df['x']>0)&(df['y']<0)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
(df['x']>0)|(df['y']<0)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
df[df['x']>0]
# Out:
#           x         y
# 0  1.189622 -1.690617
# 3  0.007315 -0.612939
# 4  1.299748 -1.733096
# 9  0.108863  0.507810

# %%
df.query('x>0')
# Out:
#           x         y
# 0  1.189622 -1.690617
# 3  0.007315 -0.612939
# 4  1.299748 -1.733096
# 9  0.108863  0.507810

# %%
df[(df['x']>0)&(df['y']<0)]
# Out:
#           x         y
# 0  1.189622 -1.690617
# 3  0.007315 -0.612939
# 4  1.299748 -1.733096

# %%
df.query('x>0 & y<0')
# Out:
#           x         y
# 0  1.189622 -1.690617
# 3  0.007315 -0.612939
# 4  1.299748 -1.733096

# %%
df[(df['x']>0)|(df['y']<0)]
# Out:
#           x         y
# 0  1.189622 -1.690617
# 1 -1.356399 -1.232435
# 2 -0.544439 -0.668172
# 3  0.007315 -0.612939
# 4  1.299748 -1.733096
# 7 -1.188018 -0.549746
# 8 -0.940046 -0.827932
# 9  0.108863  0.507810

# %%
df>0
# Out:
#        x      y
# 0   True  False
# 1  False  False
# 2  False  False
# 3   True  False
# 4   True  False
# 5  False   True
# 6  False   True
# 7  False  False
# 8  False  False
# 9   True   True

# %%
df[df>0]
# Out:
#           x         y
# 0  1.189622       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3  0.007315       NaN
# 4  1.299748       NaN
# 5       NaN  0.357508
# 6       NaN  1.470714
# 7       NaN       NaN
# 8       NaN       NaN
# 9  0.108863  0.507810

# %%
df1 = pd.DataFrame(['100', '200', '300', '400'], index=['a','b','c','d'], columns=['A',])

# %%
df1
# Out:
#      A
# a  100
# b  200
# c  300
# d  400

# %%
df2 = pd.DataFrame(['200', '150', '50'], index=['f','b','d'],columns=['B',])

# %%
df2
# Out:
#      B
# f  200
# b  150
# d   50

# %%
pd.concat((df1,df2), sort=False)
# Out:
#      A    B
# a  100  NaN
# b  200  NaN
# c  300  NaN
# d  400  NaN
# f  NaN  200
# b  NaN  150
# d  NaN   50

# %%
pd.concat((df1,df2), ignore_index=True, sort=False)
# Out:
#      A    B
# 0  100  NaN
# 1  200  NaN
# 2  300  NaN
# 3  400  NaN
# 4  NaN  200
# 5  NaN  150
# 6  NaN   50

# %%
df1.join(df2)
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df2.join(df1)
# Out:
#      B    A
# f  200  NaN
# b  150  200
# d   50  400

# %%
df1.join(df2, how='left')
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df1.join(df2, how='right')
# Out:
#      A    B
# f  NaN  200
# b  200  150
# d  400   50

# %%
df1.join(df2, how='inner')
# Out:
#      A    B
# b  200  150
# d  400   50

# %%
df1.join(df2, how='outer')
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50
# f  NaN  200

# %%
df = pd.DataFrame()

# %%
df['A'] =df1['A']

# %%
df
# Out:
#      A
# a  100
# b  200
# c  300
# d  400

# %%
df['B'] = df2

# %%
df
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df = pd.DataFrame({'A': df1['A'], 'B': df2['B']})

# %%
df
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50
# f  NaN  200

# %%
c = pd.Series([250,150,50], index=['b','d','c'])
df1['C']=c
df2['C']=c

# %%
df1
# Out:
#      A      C
# a  100    NaN
# b  200  250.0
# c  300   50.0
# d  400  150.0

# %%
df2
# Out:
#      B      C
# f  200    NaN
# b  150  250.0
# d   50  150.0

# %%
pd.merge(df1,df2)
# Out:
#      A      C    B
# 0  100    NaN  200
# 1  200  250.0  150
# 2  400  150.0   50

# %%
pd.merge(df1,df2, on='C')
# Out:
#      A      C    B
# 0  100    NaN  200
# 1  200  250.0  150
# 2  400  150.0   50

# %%
pd.merge(df1,df2,how='outer')
# outer merge is also possible, preserving all data rows
# how=outer function works weird and not same as pdf shows
# Out:
#      A      C    B
# 0  300   50.0  NaN
# 1  400  150.0   50
# 2  200  250.0  150
# 3  100    NaN  200

# %%
pd.merge(df1, df2, left_on='A', right_on='B')
# Out:
#      A    C_x    B  C_y
# 0  200  250.0  200  NaN

# %%
pd.merge(df1, df2, left_on='A', right_on='B', how='outer')
# Out:
#      A    C_x    B    C_y
# 0  100    NaN  NaN    NaN
# 1  NaN    NaN  150  250.0
# 2  200  250.0  200    NaN
# 3  300   50.0  NaN    NaN
# 4  400  150.0  NaN    NaN
# 5  NaN    NaN   50  150.0

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#      A    C_x    B    C_y
# b  200  250.0  150  250.0
# d  400  150.0   50  150.0

# %%
pd.merge_asof(df1, df2, on='C', left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 pd.merge_asof(df1, df2, on='C', left_index=True, right_index=True)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:691, in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     440 def merge_asof(
#     441     left: DataFrame | Series,
#     442     right: DataFrame | Series,
#    (...)    454     direction: str = "backward",
#     455 ) -> DataFrame:
#     456     """
#     457     Perform a merge by key distance.
#     458
#    (...)    689     4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN
#     690     """
# --> 691     op = _AsOfMerge(
#     692         left,
#     693         right,
#     694         on=on,
#     695         left_on=left_on,
#     696         right_on=right_on,
#     697         left_index=left_index,
#     698         right_index=right_index,
#     699         by=by,
#     700         left_by=left_by,
#     701         right_by=right_by,
#     702         suffixes=suffixes,
#     703         how="asof",
#     704         tolerance=tolerance,
#     705         allow_exact_matches=allow_exact_matches,
#     706         direction=direction,
#     707     )
#     708     return op.get_result()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:2000, in _AsOfMerge.__init__(self, left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, how, tolerance, allow_exact_matches, direction)
#    1994     msg = (
#    1995         "allow_exact_matches must be boolean, "
#    1996         f"passed {self.allow_exact_matches}"
#    1997     )
#    1998     raise MergeError(msg)
# -> 2000 _OrderedMerge.__init__(
#    2001     self,
#    2002     left,
#    2003     right,
#    2004     on=on,
#    2005     left_on=left_on,
#    2006     right_on=right_on,
#    2007     left_index=left_index,
#    2008     right_index=right_index,
#    2009     how=how,
#    2010     suffixes=suffixes,
#    2011     fill_method=None,
#    2012 )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1912, in _OrderedMerge.__init__(self, left, right, on, left_on, right_on, left_index, right_index, suffixes, fill_method, how)
#    1898 def __init__(
#    1899     self,
#    1900     left: DataFrame | Series,
#    (...)   1909     how: JoinHow | Literal["asof"] = "outer",
#    1910 ) -> None:
#    1911     self.fill_method = fill_method
# -> 1912     _MergeOperation.__init__(
#    1913         self,
#    1914         left,
#    1915         right,
#    1916         on=on,
#    1917         left_on=left_on,
#    1918         left_index=left_index,
#    1919         right_index=right_index,
#    1920         right_on=right_on,
#    1921         how=how,
#    1922         suffixes=suffixes,
#    1923         sort=True,  # factorize sorts
#    1924     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:786, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     779     msg = (
#     780         "Not allowed to merge between different levels. "
#     781         f"({_left.columns.nlevels} levels on the left, "
#     782         f"{_right.columns.nlevels} on the right)"
#     783     )
#     784     raise MergeError(msg)
# --> 786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#    (...)    793     right_drop,
#     794 ) = self._get_merge_keys()
#     796 if left_drop:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:2015, in _AsOfMerge._validate_left_right_on(self, left_on, right_on)
#    2014 def _validate_left_right_on(self, left_on, right_on):
# -> 2015     left_on, right_on = super()._validate_left_right_on(left_on, right_on)
#    2017     # we only allow on to be a single item for on
#    2018     if len(left_on) != 1 and not self.left_index:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1593, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1588         raise MergeError(
#    1589             'Can only pass argument "on" OR "left_on" '
#    1590             'and "right_on", not a combination of both.'
#    1591         )
#    1592     if self.left_index or self.right_index:
# -> 1593         raise MergeError(
#    1594             'Can only pass argument "on" OR "left_index" '
#    1595             'and "right_index", not a combination of both.'
#    1596         )
#    1597     left_on = right_on = self.on
#    1598 elif left_on is not None:
#
# MergeError: Can only pass argument "on" OR "left_index" and "right_index", not a combination of both.

# %%
data = np.random.standard_normal((1000000, 2))

# %%
data.nbytes
# Out:
# 16000000

# %%
df = pd.DataFrame(data, columns=['x', 'y'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   x       1000000 non-null  float64
#  1   y       1000000 non-null  float64
# dtypes: float64(2)
# memory usage: 15.3 MB

# %%
df
# Out:
#                x         y
# 0      -0.862227  1.249470
# 1      -0.079611 -0.889731
# 2      -0.881798  0.018639
# 3       0.237845  0.013549
# 4      -1.635529 -1.044210
# ...          ...       ...
# 999995  0.278500 -0.082883
# 999996 -0.082425 -0.938858
# 999997 -1.295128 -1.374231
# 999998 -0.505550 -0.426536
# 999999  0.756792  0.248269
#
# [1000000 rows x 2 columns]

# %%
# %time res = df['x']+df['y']
#Working with the columns (Series objects) directly is the fastest approach.
# Out:
# CPU times: total: 0 ns
# Wall time: 4.17 ms

# %%
res[:3]
# Out:
# 0    0.387242
# 1   -0.969343
# 2   -0.863159
# dtype: float64

# %%
# %time res = df.sum(axis=1)
#This calculates the sums by calling the sum() method on the DataFrame object.
# Out:
# CPU times: total: 78.1 ms
# Wall time: 94.6 ms

# %%
res[:3]
# Out:
# 0    0.387242
# 1   -0.969343
# 2   -0.863159
# dtype: float64

# %%
# %time res = df.values.sum(axis=1)
#This calculates the sums by calling the sum() method on the ndarray object.
# Out:
# CPU times: total: 15.6 ms
# Wall time: 12.3 ms

# %%
res[:3]
# Out:
# array([ 0.3872424 , -0.96934273, -0.86315944])

# %%
# %time res = np.sum(df, axis=1)
#This calculates the sums by using the function np.sum() on the DataFrameobject.
# Out:
# CPU times: total: 109 ms
# Wall time: 109 ms

# %%
res[:3]
# Out:
# 0    0.387242
# 1   -0.969343
# 2   -0.863159
# dtype: float64

# %%
# %time res = np.sum(df.values, axis=1)
#This calculates the sums by using the function np.sum() on the ndarray object.
# Out:
# CPU times: total: 15.6 ms
# Wall time: 9.52 ms

# %%
res[:3]
# Out:
# array([ 0.3872424 , -0.96934273, -0.86315944])

# %%
# %time res = df.eval('x + y')
#eval() is a method dedicated to evaluation of (complex) numerical expressions; columns can be directly addressed.
# Out:
# CPU times: total: 15.6 ms
# Wall time: 10.4 ms

# %%
res[:3]
# Out:
# 0    0.387242
# 1   -0.969343
# 2   -0.863159
# dtype: float64

# %%
# %time res = df.apply(lambda row: row['x'] + row['y'], axis=1)
#The slowest option is to use the apply() method row-by-row; this is like looping on the Python level over all rows.
# Out:
# CPU times: total: 3.67 s
# Wall time: 3.83 s

# %%
res[:3]
# Out:
# 0    0.387242
# 1   -0.969343
# 2   -0.863159
# dtype: float64
