# %% [markdown]
# PARTIV . ALgorithmic Trading

# %% [markdown]
# Chapter 14. The FXCM Trading Platform

# %%
# !pip install fxcmpy
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for fxcmpy: filename=fxcmpy-0.0.0.1-py3-none-any.whl size=1306 sha256=c283654818afc78b405495ad6bc75a8e38966c06ced5bbc7c3017b27517bb6f6
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\95\1f\05\9d191badac09af9f2c9cfc4b7604abe8e8d0a93c23485b0607
# Successfully built fxcmpy
# ...
