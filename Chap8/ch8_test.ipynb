# %% [markdown]
# Chapter 8 : Financial Time Series

# %%
import numpy as np
import pandas as pd
from pylab import mpl, plt
plt.style.use('seaborn-v0_8-paper')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
filename = 'tr_eikon_eod_data.csv'

# %%
f = open(filename, 'r')
f.readlines()[:5]
# Out:
# ['Date,AAPL.O,MSFT.O,INTC.O,AMZN.O,GS.N,SPY,.SPX,.VIX,EUR=,XAU=,GDX,GLD\n',
#  '2010-01-01,,,,,,,,,1.4323,1096.35,,\n',
#  '2010-01-04,30.57282657,30.95,20.88,133.9,173.08,113.33,1132.99,20.04,1.4411,1120.0,47.71,109.8\n',
#  '2010-01-05,30.625683660000004,30.96,20.87,134.69,176.14,113.63,1136.52,19.35,1.4368,1118.65,48.17,109.7\n',
#  '2010-01-06,30.138541290000003,30.77,20.8,132.25,174.26,113.71,1137.14,19.16,1.4412,1138.5,49.34,111.51\n']

# %%
data = pd.read_csv(filename,  
                           index_col=0, 
                           parse_dates=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2216 entries, 2010-01-01 to 2018-06-29
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2138 non-null   float64
#  1   MSFT.O  2138 non-null   float64
#  2   INTC.O  2138 non-null   float64
#  3   AMZN.O  2138 non-null   float64
#  4   GS.N    2138 non-null   float64
#  5   SPY     2138 non-null   float64
#  6   .SPX    2138 non-null   float64
#  7   .VIX    2138 non-null   float64
#  8   EUR=    2216 non-null   float64
#  9   XAU=    2211 non-null   float64
#  10  GDX     2138 non-null   float64
#  11  GLD     2138 non-null   float64
# dtypes: float64(12)
# memory usage: 225.1 KB

# %%
data.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-01  1.4323  1096.35    NaN     NaN
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82

# %%
data.tail()
# Out:
#             AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2018-06-25  182.17   98.39   50.71  1663.15  221.54  271.00  2717.07  17.33
# 2018-06-26  184.43   99.08   49.67  1691.09  221.58  271.60  2723.06  15.92
# 2018-06-27  184.16   97.54   48.76  1660.51  220.18  269.35  2699.63  17.91
# 2018-06-28  185.50   98.63   49.25  1701.45  223.42  270.89  2716.31  16.85
# 2018-06-29  185.11   98.61   49.71  1699.80  220.57  271.28  2718.37  16.09
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2018-06-25  1.1702  1265.00  22.01  119.89
# 2018-06-26  1.1645  1258.64  21.95  119.26
# 2018-06-27  1.1552  1251.62  21.81  118.58
# 2018-06-28  1.1567  1247.88  21.93  118.22
# 2018-06-29  1.1683  1252.25  22.31  118.65

# %%
data.plot(figsize=(10,12), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
instruments = ['Apple Stock', 'Microsoft Stock',
                       'Intel Stock', 'Amazon Stock', 'Goldman Sachs Stock',
                       'SPDR S&P 500 ETF Trust', 'S&P 500 Index',
                       'VIX Volatility Index', 'EUR/USD Exchange Rate',
                       'Gold Price', 'VanEck Vectors Gold Miners ETF',
                       'SPDR Gold Trust']

# %%
for ric, name in zip(data.columns, instruments):
    print('{:8s}|{}'.format(ric, name))
# Out:
# AAPL.O  |Apple Stock
# MSFT.O  |Microsoft Stock
# INTC.O  |Intel Stock
# AMZN.O  |Amazon Stock
# GS.N    |Goldman Sachs Stock
# SPY     |SPDR S&P 500 ETF Trust
# .SPX    |S&P 500 Index
# .VIX    |VIX Volatility Index
# EUR=    |EUR/USD Exchange Rate
# XAU=    |Gold Price
# GDX     |VanEck Vectors Gold Miners ETF
# GLD     |SPDR Gold Trust

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2216 entries, 2010-01-01 to 2018-06-29
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2138 non-null   float64
#  1   MSFT.O  2138 non-null   float64
#  2   INTC.O  2138 non-null   float64
#  3   AMZN.O  2138 non-null   float64
#  4   GS.N    2138 non-null   float64
#  5   SPY     2138 non-null   float64
#  6   .SPX    2138 non-null   float64
#  7   .VIX    2138 non-null   float64
#  8   EUR=    2216 non-null   float64
#  9   XAU=    2211 non-null   float64
#  10  GDX     2138 non-null   float64
#  11  GLD     2138 non-null   float64
# dtypes: float64(12)
# memory usage: 225.1 KB

# %%
data.describe().round(2)
# Out:
#         AAPL.O   MSFT.O   INTC.O   AMZN.O     GS.N      SPY     .SPX     .VIX  \
# count  2138.00  2138.00  2138.00  2138.00  2138.00  2138.00  2138.00  2138.00
# mean     93.46    44.56    29.36   480.46   170.22   180.32  1802.71    17.03
# std      40.55    19.53     8.17   372.31    42.48    48.19   483.34     5.88
# min      27.44    23.01    17.66   108.61    87.70   102.20  1022.58     9.14
# 25%      60.29    28.57    22.51   213.60   146.61   133.99  1338.57    13.07
# 50%      90.55    39.66    27.33   322.06   164.43   186.32  1863.08    15.58
# 75%     117.24    54.37    34.71   698.85   192.13   210.99  2108.94    19.07
# max     193.98   102.49    57.08  1750.08   273.38   286.58  2872.87    48.00
#
#           EUR=     XAU=      GDX      GLD
# count  2216.00  2211.00  2138.00  2138.00
# mean      1.25  1349.01    33.57   130.09
# std       0.11   188.75    15.17    18.78
# min       1.04  1051.36    12.47   100.50
# 25%       1.13  1221.53    22.14   117.40
# 50%       1.27  1292.61    25.62   124.00
# 75%       1.35  1428.24    48.34   139.00
# max       1.48  1898.99    66.63   184.59

# %%
data.mean()
# Out:
# AAPL.O      93.455973
# MSFT.O      44.561115
# INTC.O      29.364192
# AMZN.O     480.461251
# GS.N       170.216221
# SPY        180.323029
# .SPX      1802.713106
# .VIX        17.027133
# EUR=         1.248587
# XAU=      1349.014130
# GDX         33.566525
# GLD        130.086590
# dtype: float64

# %%
data.aggregate([min,  
                         np.mean,  
                         np.std,  
                         np.median,  
                         max]  
         ).round(2)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function mean at 0x00000247CF27A840> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function std at 0x00000247CF27A980> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <function median at 0x00000247CF3A4400> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data.aggregate([min,
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_27884\3757841646.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data.aggregate([min,
#         AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY     .SPX   .VIX  EUR=  \
# min      27.44   23.01   17.66   108.61   87.70  102.20  1022.58   9.14  1.04
# mean     93.46   44.56   29.36   480.46  170.22  180.32  1802.71  17.03  1.25
# std      40.55   19.53    8.17   372.31   42.48   48.19   483.34   5.88  0.11
# median   90.55   39.66   27.33   322.06  164.43  186.32  1863.08  15.58  1.27
# max     193.98  102.49   57.08  1750.08  273.38  286.58  2872.87  48.00  1.48
#
#            XAU=    GDX     GLD
# min     1051.36  12.47  100.50
# mean    1349.01  33.57  130.09
# std      188.75  15.17   18.78
# median  1292.61  25.62  124.00
# max     1898.99  66.63  184.59

# %%
data.diff().head()
# Out:
#               AAPL.O  MSFT.O  INTC.O  AMZN.O  GS.N   SPY  .SPX  .VIX    EUR=  \
# Date
# 2010-01-01       NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN     NaN
# 2010-01-04       NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN  0.0088
# 2010-01-05  0.052857   0.010   -0.01    0.79  3.06  0.30  3.53 -0.69 -0.0043
# 2010-01-06 -0.487142  -0.190   -0.07   -2.44 -1.88  0.08  0.62 -0.19  0.0044
# 2010-01-07 -0.055714  -0.318   -0.20   -2.25  3.41  0.48  4.55 -0.10 -0.0094
#
#              XAU=   GDX   GLD
# Date
# 2010-01-01    NaN   NaN   NaN
# 2010-01-04  23.65   NaN   NaN
# 2010-01-05  -1.35  0.46 -0.10
# 2010-01-06  19.85  1.17  1.81
# 2010-01-07  -6.60 -0.24 -0.69
